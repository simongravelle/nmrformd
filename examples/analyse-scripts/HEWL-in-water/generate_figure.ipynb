# %%
import os
import numpy as np
import MDAnalysis as mda

import matplotlib.pyplot as plt

all_folders = ["T300K_ratio0.11/", "T300K_ratio0.61/"]

for folder in all_folders:

    data = np.load(folder[:-1]+"_analysed-all-data.npy", allow_pickle=True)
    nmr_all_f = data.item()["nmr_all_f"]
    nmr_all_R1 = data.item()["nmr_all_R1"]
    nmr_all_R2 = data.item()["nmr_all_R2"]

    plt.loglog(nmr_all_f, 1/nmr_all_R1, '.')

    plt.loglog(nmr_all_f, 1/nmr_all_R2, '.')

# %%
    dictionary = {
        "nmr_all_f": nmr_all_all.f,
        "nmr_all_R1": nmr_all_all.R1,
        "nmr_all_R2": nmr_all_all.R2,
    }
    np.save(folder[:-1]+"_analysed-all-data.npy", dictionary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 dictionary = {
# ----> 2     "nmr_all_f": nmr_all_all.f,
#       3     "nmr_all_R1": nmr_all_all.R1,
#       4     "nmr_all_R2": nmr_all_all.R2,
#       5 }
#       6 np.save(folder[:-1]+"_analysed-all-data.npy", dictionary)
#
# NameError: name 'nmr_all_all' is not defined
